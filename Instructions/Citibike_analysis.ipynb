# %%
import pandas as pd
import datetime

# %%
data_path="Resources/"

# %%
df1=pd.read_csv(data_path + "JC-202001-citibike-tripdata_1.csv")
df1
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 26015           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 26016           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 26017           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 26018           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 26019           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#        start station id          start station name  start station latitude  \
# ...

# %%
#df.Name.str.split("_",expand=True) 
   
df1['starttime'].str.split(" ",n=1,expand=True)[0]
# Out:
# 0        2020-01-01
# 1        2020-01-01
# 2        2020-01-01
# 3        2020-01-01
# 4        2020-01-01
#             ...
# 26015    2020-01-31
# 26016    2020-01-31
# 26017    2020-01-31
# 26018    2020-01-31
# 26019    2020-01-31
# Name: 0, Length: 26020, dtype: object

# %%
df2=pd.read_csv(data_path + "JC-202002-citibike-tripdata_2.csv")
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1           206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2           859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3           693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4          1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
#
#    start station id  start station name  start station latitude  \
# 0              3199        Newport Pkwy               40.728745
# 1              3273        Manila & 1st               40.721651
# 2              3185           City Hall               40.717733
# 3              3185           City Hall               40.717733
# 4              3192  Liberty Light Rail               40.711242
#
#    start station longitude  end station id         end station name  \
# 0               -74.032108            3213           Van Vorst Park
# ...

# %%
df2['starttime'].str.split(" ",n=1,expand=True)[0]
# Out:
# 0        2020-02-01
# 1        2020-02-01
# 2        2020-02-01
# 3        2020-02-01
# 4        2020-02-01
#             ...
# 22957    2020-02-29
# 22958    2020-02-29
# 22959    2020-02-29
# 22960    2020-02-29
# 22961    2020-02-29
# Name: 0, Length: 22962, dtype: object

# %%
# df.append(df2, ignore_index=True)
  
append_df = df1.append(df2,ignore_index=True)

# %%
append_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1               236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2               384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3              1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4              5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
# ...             ...                       ...                       ...
# 97095           270  2020-10-13 15:05:35.0860  2020-10-13 15:10:05.3430
# 97096           400  2020-10-13 15:09:03.4890  2020-10-13 15:15:43.9750
# 97097           206  2020-10-13 15:11:34.3500  2020-10-13 15:15:00.5030
# 97098           216  2020-10-13 15:11:49.1510  2020-10-13 15:15:25.6930
# 97099           418  2020-10-13 15:12:31.7920  2020-10-13 15:19:30.5280
#
#        start station id start station name  start station latitude  \
# ...

# %%
df3=pd.read_csv(data_path + "JC-202003-citibike-tripdata_3.csv")
df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1           242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2           124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3           104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4           228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3185          City Hall               40.717733
# 2              3272       Jersey & 3rd               40.723332
# 3              3202       Newport PATH               40.727224
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id   end station name  \
# 0               -74.033759            3203      Hamilton Park
# ...

# %%
df4=pd.read_csv(data_path + "JC-202004-citibike-tripdata_4.csv")
df4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1           264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2           254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3           429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4           805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
#
#    start station id start station name  start station latitude  \
# 0              3678      Fairmount Ave               40.725726
# 1              3207        Oakland Ave               40.737604
# 2              3678      Fairmount Ave               40.725726
# 3              3195            Sip Ave               40.730897
# 4              3193       Lincoln Park               40.724605
#
#    start station longitude  end station id end station name  \
# 0               -74.071959            3678    Fairmount Ave
# ...

# %%
df5=pd.read_csv(data_path + "JC-202005-citibike-tripdata_5.csv")
df5.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1           138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2           229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3           261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4           168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
#
#    start station id          start station name  start station latitude  \
# 0              3195                     Sip Ave               40.730897
# 1              3792  Columbus Dr at Exchange Pl               40.716870
# 2              3483               Montgomery St               40.719420
# 3              3278            Monmouth and 6th               40.725685
# 4              3194             McGinley Square               40.725340
#
#    start station longitude  end station id end station name  \
# ...

# %%
df6=pd.read_csv(data_path + "JC-202006-citibike-tripdata_6.csv")
df6.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#    start station id          start station name  start station latitude  \
# 0              3792  Columbus Dr at Exchange Pl               40.716870
# 1              3198            Heights Elevator               40.748716
# 2              3275              Columbus Drive               40.718355
# 3              3267                Morris Canal               40.712419
# 4              3639                  Harborside               40.719252
#
#    start station longitude  end station id  end station name  \
# ...

# %%
df7=pd.read_csv(data_path + "JC-202007-citibike-tripdata_7.csv")
df7.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3          1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4          2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
#
#    start station id          start station name  start station latitude  \
# 0              3694              Jackson Square               40.711130
# 1              3791  Hoboken Ave at Monmouth St               40.735208
# 2              3792  Columbus Dr at Exchange Pl               40.716870
# 3              3677                Glenwood Ave               40.727551
# 4              3191                    Union St               40.718211
#
#    start station longitude  end station id       end station name  \
# ...

# %%
df8=pd.read_csv(data_path + "JC-202008-citibike-tripdata_8.csv")
df8.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1           236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2           384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3          1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4          5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717733
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3185          City Hall               40.717733
# 4              3185          City Hall               40.717733
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3185        City Hall
# ...

# %%
df9=pd.read_csv(data_path + "JC-202009-citibike-tripdata_9.csv")
df9.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           222  2020-09-01 00:15:58.6470  2020-09-01 00:19:40.8750
# 1           193  2020-09-01 00:49:00.7370  2020-09-01 00:52:14.3640
# 2           273  2020-09-01 00:51:44.5870  2020-09-01 00:56:17.7160
# 3          1419  2020-09-01 00:52:48.3160  2020-09-01 01:16:28.0490
# 4           254  2020-09-01 00:56:16.7170  2020-09-01 01:00:31.0870
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3640     Journal Square               40.733670
# 2              3191           Union St               40.718211
# 3              3203      Hamilton Park               40.727596
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3276  Marin Light Rail
# ...

# %%
df10=pd.read_csv(data_path + "JC-201912-citibike-tripdata_10.csv")
df10.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1           416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2           294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3            97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4           286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
#
#    start station id start station name  start station latitude  \
# 0              3681           Grand St               40.715178
# 1              3195            Sip Ave               40.730897
# 2              3195            Sip Ave               40.730897
# 3              3202       Newport PATH               40.727224
# 4              3195            Sip Ave               40.730897
#
#    start station longitude  end station id  end station name  \
# 0               -74.037683            3198  Heights Elevator
# ...

# %%
citibike_2020 = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10])
citibike_2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 19723           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 19724           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 19725           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 19726           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 19727           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Convert  Dataframe to csv

citibike_2020.to_csv('citibike_2020.csv', sep = ',')
